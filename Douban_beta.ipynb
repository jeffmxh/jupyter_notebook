# %%
import re
import requests
import bs4

from bs4 import BeautifulSoup
from collections import namedtuple

# %%
home_url = 'https://movie.douban.com'

def get_URL(url):
    headers = {'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54.0) Gecko/20100101 Firefox/54.0'}
    response = requests.get(url, headers=headers)
    return response.text

def get_urlSoup(url):
    headers = {'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54.0) Gecko/20100101 Firefox/54.0'}
    response = requests.get(url, headers=headers)
    soup = BeautifulSoup(response.text, 'lxml')
    return soup

def parse_movieURL(url, home='https://movie.douban.com'):
    text = get_URL(url)
    movie_pattern = re.compile('/subject/[0-9]+?/')
    movie_index = movie_pattern.findall(text)
    movies = set([home + x for x in movie_index])
    return movies

def collect_movieURL(home_url, movies_prime = set(), max_iter = 5):
    if len(movies_prime)==0:
        movies = parse_movieURL(url=home_url, home=home_url)
    else:
        movies = movies_prime
    new_movies_temp = movies
    for step in range(max_iter):
        new_movies = set()
        nobj = len(new_movies_temp)
        totalNum = len(movies)
        for sub_step, url in enumerate(new_movies_temp):
            movies_temp = parse_movieURL(url) - movies
            new_movies = (new_movies | movies_temp)
            movies = movies | new_movies
            print('Global iter %d, local step %d/%d, fetch %d new movies!, total: %d ' % 
              (step+1, sub_step+1, nobj, len(movies_temp), len(movies)))
        new_movies_temp = new_movies
        if len(movies)-totalNum < 10:
            break
    return movies

# movies = parse_movieURL(home_url)
new_movies = collect_movieURL(home_url, movies, 2)
# a = parse_movieURL(home_url)
# b = parse_movieURL('https://movie.douban.com/subject/22266126/')
# b-a
# Out:
# Global iter 1, local step 1/2336, fetch 1 new movies!, total: 2337
# Global iter 1, local step 2/2336, fetch 4 new movies!, total: 2341
# Global iter 1, local step 3/2336, fetch 6 new movies!, total: 2347
# Global iter 1, local step 4/2336, fetch 5 new movies!, total: 2352
# Global iter 1, local step 5/2336, fetch 1 new movies!, total: 2353
# Global iter 1, local step 6/2336, fetch 0 new movies!, total: 2353
# Global iter 1, local step 7/2336, fetch 0 new movies!, total: 2353
# Global iter 1, local step 8/2336, fetch 7 new movies!, total: 2360
# Global iter 1, local step 9/2336, fetch 3 new movies!, total: 2363
# Global iter 1, local step 10/2336, fetch 0 new movies!, total: 2363
# Global iter 1, local step 11/2336, fetch 4 new movies!, total: 2367
# Global iter 1, local step 12/2336, fetch 6 new movies!, total: 2373
# Global iter 1, local step 13/2336, fetch 8 new movies!, total: 2381
# Global iter 1, local step 14/2336, fetch 3 new movies!, total: 2384
# Global iter 1, local step 15/2336, fetch 0 new movies!, total: 2384
# Global iter 1, local step 16/2336, fetch 0 new movies!, total: 2384
# Global iter 1, local step 17/2336, fetch 0 new movies!, total: 2384
# Global iter 1, local step 18/2336, fetch 2 new movies!, total: 2386
# Global iter 1, local step 19/2336, fetch 0 new movies!, total: 2386
# Global iter 1, local step 20/2336, fetch 9 new movies!, total: 2395
# Global iter 1, local step 21/2336, fetch 8 new movies!, total: 2403
# Global iter 1, local step 22/2336, fetch 0 new movies!, total: 2403
# Global iter 1, local step 23/2336, fetch 3 new movies!, total: 2406
# Global iter 1, local step 24/2336, fetch 0 new movies!, total: 2406
# Global iter 1, local step 25/2336, fetch 0 new movies!, total: 2406
# Global iter 1, local step 26/2336, fetch 6 new movies!, total: 2412
# Global iter 1, local step 27/2336, fetch 0 new movies!, total: 2412
# Global iter 1, local step 28/2336, fetch 4 new movies!, total: 2416
# Global iter 1, local step 29/2336, fetch 5 new movies!, total: 2421
# Global iter 1, local step 30/2336, fetch 0 new movies!, total: 2421
# Global iter 1, local step 31/2336, fetch 5 new movies!, total: 2426
# Global iter 1, local step 32/2336, fetch 1 new movies!, total: 2427
# Global iter 1, local step 33/2336, fetch 6 new movies!, total: 2433
# Global iter 1, local step 34/2336, fetch 0 new movies!, total: 2433
# Global iter 1, local step 35/2336, fetch 4 new movies!, total: 2437
# Global iter 1, local step 36/2336, fetch 3 new movies!, total: 2440
# Global iter 1, local step 37/2336, fetch 8 new movies!, total: 2448
# Global iter 1, local step 38/2336, fetch 5 new movies!, total: 2453
# Global iter 1, local step 39/2336, fetch 2 new movies!, total: 2455
# Global iter 1, local step 40/2336, fetch 1 new movies!, total: 2456
# Global iter 1, local step 41/2336, fetch 3 new movies!, total: 2459
# Global iter 1, local step 42/2336, fetch 0 new movies!, total: 2459
# Global iter 1, local step 43/2336, fetch 6 new movies!, total: 2465
# Global iter 1, local step 44/2336, fetch 2 new movies!, total: 2467
# Global iter 1, local step 45/2336, fetch 0 new movies!, total: 2467
# Global iter 1, local step 46/2336, fetch 6 new movies!, total: 2473
# Global iter 1, local step 47/2336, fetch 1 new movies!, total: 2474
# Global iter 1, local step 48/2336, fetch 0 new movies!, total: 2474
# Global iter 1, local step 49/2336, fetch 0 new movies!, total: 2474
# Global iter 1, local step 50/2336, fetch 0 new movies!, total: 2474
# Global iter 1, local step 51/2336, fetch 0 new movies!, total: 2474
# Global iter 1, local step 52/2336, fetch 2 new movies!, total: 2476
# Global iter 1, local step 53/2336, fetch 0 new movies!, total: 2476
# Global iter 1, local step 54/2336, fetch 0 new movies!, total: 2476
# Global iter 1, local step 55/2336, fetch 1 new movies!, total: 2477
# Global iter 1, local step 56/2336, fetch 9 new movies!, total: 2486
# Global iter 1, local step 57/2336, fetch 4 new movies!, total: 2490
# Global iter 1, local step 58/2336, fetch 1 new movies!, total: 2491
# Global iter 1, local step 59/2336, fetch 7 new movies!, total: 2498
# Global iter 1, local step 60/2336, fetch 5 new movies!, total: 2503
# Global iter 1, local step 61/2336, fetch 10 new movies!, total: 2513
# Global iter 1, local step 62/2336, fetch 0 new movies!, total: 2513
# Global iter 1, local step 63/2336, fetch 5 new movies!, total: 2518
# Global iter 1, local step 64/2336, fetch 4 new movies!, total: 2522
# Global iter 1, local step 65/2336, fetch 1 new movies!, total: 2523
# Global iter 1, local step 66/2336, fetch 6 new movies!, total: 2529
# Global iter 1, local step 67/2336, fetch 4 new movies!, total: 2533
# Global iter 1, local step 68/2336, fetch 3 new movies!, total: 2536
# Global iter 1, local step 69/2336, fetch 7 new movies!, total: 2543
# Global iter 1, local step 70/2336, fetch 0 new movies!, total: 2543
# Global iter 1, local step 71/2336, fetch 4 new movies!, total: 2547
# Global iter 1, local step 72/2336, fetch 0 new movies!, total: 2547
# Global iter 1, local step 73/2336, fetch 2 new movies!, total: 2549
# Global iter 1, local step 74/2336, fetch 9 new movies!, total: 2558
# Global iter 1, local step 75/2336, fetch 0 new movies!, total: 2558
# Global iter 1, local step 76/2336, fetch 8 new movies!, total: 2566
# Global iter 1, local step 77/2336, fetch 3 new movies!, total: 2569
# Global iter 1, local step 78/2336, fetch 10 new movies!, total: 2579
# Global iter 1, local step 79/2336, fetch 9 new movies!, total: 2588
# Global iter 1, local step 80/2336, fetch 2 new movies!, total: 2590
# Global iter 1, local step 81/2336, fetch 0 new movies!, total: 2590
# Global iter 1, local step 82/2336, fetch 1 new movies!, total: 2591
# Global iter 1, local step 83/2336, fetch 1 new movies!, total: 2592
# Global iter 1, local step 84/2336, fetch 3 new movies!, total: 2595
# Global iter 1, local step 85/2336, fetch 8 new movies!, total: 2603
# Global iter 1, local step 86/2336, fetch 3 new movies!, total: 2606
# Global iter 1, local step 87/2336, fetch 0 new movies!, total: 2606
# Global iter 1, local step 88/2336, fetch 7 new movies!, total: 2613
# Global iter 1, local step 89/2336, fetch 1 new movies!, total: 2614
# Global iter 1, local step 90/2336, fetch 8 new movies!, total: 2622
# Global iter 1, local step 91/2336, fetch 0 new movies!, total: 2622
# Global iter 1, local step 92/2336, fetch 7 new movies!, total: 2629
# Global iter 1, local step 93/2336, fetch 0 new movies!, total: 2629
# Global iter 1, local step 94/2336, fetch 0 new movies!, total: 2629
# Global iter 1, local step 95/2336, fetch 4 new movies!, total: 2633
# Global iter 1, local step 96/2336, fetch 9 new movies!, total: 2642
# Global iter 1, local step 97/2336, fetch 5 new movies!, total: 2647
# Global iter 1, local step 98/2336, fetch 0 new movies!, total: 2647
# Global iter 1, local step 99/2336, fetch 0 new movies!, total: 2647
# Global iter 1, local step 100/2336, fetch 1 new movies!, total: 2648
# Global iter 1, local step 101/2336, fetch 8 new movies!, total: 2656
# Global iter 1, local step 102/2336, fetch 1 new movies!, total: 2657
# Global iter 1, local step 103/2336, fetch 0 new movies!, total: 2657
# Global iter 1, local step 104/2336, fetch 4 new movies!, total: 2661
# Global iter 1, local step 105/2336, fetch 8 new movies!, total: 2669
# Global iter 1, local step 106/2336, fetch 0 new movies!, total: 2669
# Global iter 1, local step 107/2336, fetch 2 new movies!, total: 2671
# Global iter 1, local step 108/2336, fetch 0 new movies!, total: 2671
# Global iter 1, local step 109/2336, fetch 6 new movies!, total: 2677
# Global iter 1, local step 110/2336, fetch 8 new movies!, total: 2685
# Global iter 1, local step 111/2336, fetch 2 new movies!, total: 2687
# Global iter 1, local step 112/2336, fetch 0 new movies!, total: 2687
# Global iter 1, local step 113/2336, fetch 0 new movies!, total: 2687
# Global iter 1, local step 114/2336, fetch 1 new movies!, total: 2688
# Global iter 1, local step 115/2336, fetch 0 new movies!, total: 2688
# Global iter 1, local step 116/2336, fetch 6 new movies!, total: 2694
# Global iter 1, local step 117/2336, fetch 7 new movies!, total: 2701
# Global iter 1, local step 118/2336, fetch 1 new movies!, total: 2702
# Global iter 1, local step 119/2336, fetch 9 new movies!, total: 2711
# Global iter 1, local step 120/2336, fetch 7 new movies!, total: 2718
# Global iter 1, local step 121/2336, fetch 0 new movies!, total: 2718
# Global iter 1, local step 122/2336, fetch 9 new movies!, total: 2727
# Global iter 1, local step 123/2336, fetch 0 new movies!, total: 2727
# Global iter 1, local step 124/2336, fetch 3 new movies!, total: 2730
# Global iter 1, local step 125/2336, fetch 2 new movies!, total: 2732
# Global iter 1, local step 126/2336, fetch 0 new movies!, total: 2732
# Global iter 1, local step 127/2336, fetch 0 new movies!, total: 2732
# Global iter 1, local step 128/2336, fetch 0 new movies!, total: 2732
# Global iter 1, local step 129/2336, fetch 8 new movies!, total: 2740
# Global iter 1, local step 130/2336, fetch 0 new movies!, total: 2740
# Global iter 1, local step 131/2336, fetch 7 new movies!, total: 2747
# Global iter 1, local step 132/2336, fetch 0 new movies!, total: 2747
# Global iter 1, local step 133/2336, fetch 6 new movies!, total: 2753
# Global iter 1, local step 134/2336, fetch 7 new movies!, total: 2760
# Global iter 1, local step 135/2336, fetch 0 new movies!, total: 2760
# Global iter 1, local step 136/2336, fetch 1 new movies!, total: 2761
# Global iter 1, local step 137/2336, fetch 7 new movies!, total: 2768
# Global iter 1, local step 138/2336, fetch 2 new movies!, total: 2770
# Global iter 1, local step 139/2336, fetch 4 new movies!, total: 2774
# Global iter 1, local step 140/2336, fetch 0 new movies!, total: 2774
# Global iter 1, local step 141/2336, fetch 6 new movies!, total: 2780
# Global iter 1, local step 142/2336, fetch 1 new movies!, total: 2781
# Global iter 1, local step 143/2336, fetch 0 new movies!, total: 2781
# Global iter 1, local step 144/2336, fetch 0 new movies!, total: 2781
# Global iter 1, local step 145/2336, fetch 5 new movies!, total: 2786
# Global iter 1, local step 146/2336, fetch 7 new movies!, total: 2793
# Global iter 1, local step 147/2336, fetch 0 new movies!, total: 2793
# Global iter 1, local step 148/2336, fetch 3 new movies!, total: 2796
# Global iter 1, local step 149/2336, fetch 0 new movies!, total: 2796
# Global iter 1, local step 150/2336, fetch 2 new movies!, total: 2798
# Global iter 1, local step 151/2336, fetch 0 new movies!, total: 2798
# Global iter 1, local step 152/2336, fetch 0 new movies!, total: 2798
# Global iter 1, local step 153/2336, fetch 7 new movies!, total: 2805
# Global iter 1, local step 154/2336, fetch 0 new movies!, total: 2805
# Global iter 1, local step 155/2336, fetch 5 new movies!, total: 2810
# Global iter 1, local step 156/2336, fetch 4 new movies!, total: 2814
# Global iter 1, local step 157/2336, fetch 7 new movies!, total: 2821
# Global iter 1, local step 158/2336, fetch 0 new movies!, total: 2821
# Global iter 1, local step 159/2336, fetch 8 new movies!, total: 2829
# Global iter 1, local step 160/2336, fetch 7 new movies!, total: 2836
# Global iter 1, local step 161/2336, fetch 9 new movies!, total: 2845
# Global iter 1, local step 162/2336, fetch 9 new movies!, total: 2854
# Global iter 1, local step 163/2336, fetch 0 new movies!, total: 2854
# Global iter 1, local step 164/2336, fetch 0 new movies!, total: 2854
# Global iter 1, local step 165/2336, fetch 0 new movies!, total: 2854
# Global iter 1, local step 166/2336, fetch 0 new movies!, total: 2854
# Global iter 1, local step 167/2336, fetch 3 new movies!, total: 2857
# Global iter 1, local step 168/2336, fetch 0 new movies!, total: 2857
# Global iter 1, local step 169/2336, fetch 0 new movies!, total: 2857
# Global iter 1, local step 170/2336, fetch 3 new movies!, total: 2860
# Global iter 1, local step 171/2336, fetch 7 new movies!, total: 2867
# Global iter 1, local step 172/2336, fetch 0 new movies!, total: 2867
# Global iter 1, local step 173/2336, fetch 7 new movies!, total: 2874
# Global iter 1, local step 174/2336, fetch 8 new movies!, total: 2882
# Global iter 1, local step 175/2336, fetch 2 new movies!, total: 2884
# Global iter 1, local step 176/2336, fetch 9 new movies!, total: 2893
# Global iter 1, local step 177/2336, fetch 7 new movies!, total: 2900
# Global iter 1, local step 178/2336, fetch 8 new movies!, total: 2908
# Global iter 1, local step 179/2336, fetch 1 new movies!, total: 2909
# Global iter 1, local step 180/2336, fetch 3 new movies!, total: 2912
# Global iter 1, local step 181/2336, fetch 2 new movies!, total: 2914
# Global iter 1, local step 182/2336, fetch 3 new movies!, total: 2917
# Global iter 1, local step 183/2336, fetch 0 new movies!, total: 2917
# Global iter 1, local step 184/2336, fetch 0 new movies!, total: 2917
# Global iter 1, local step 185/2336, fetch 5 new movies!, total: 2922
# Global iter 1, local step 186/2336, fetch 1 new movies!, total: 2923
# Global iter 1, local step 187/2336, fetch 3 new movies!, total: 2926
# Global iter 1, local step 188/2336, fetch 3 new movies!, total: 2929
# Global iter 1, local step 189/2336, fetch 6 new movies!, total: 2935
# Global iter 1, local step 190/2336, fetch 0 new movies!, total: 2935
# Global iter 1, local step 191/2336, fetch 0 new movies!, total: 2935
# Global iter 1, local step 192/2336, fetch 0 new movies!, total: 2935
# Global iter 1, local step 193/2336, fetch 5 new movies!, total: 2940
# Global iter 1, local step 194/2336, fetch 6 new movies!, total: 2946
# Global iter 1, local step 195/2336, fetch 9 new movies!, total: 2955
# Global iter 1, local step 196/2336, fetch 4 new movies!, total: 2959
# Global iter 1, local step 197/2336, fetch 5 new movies!, total: 2964
# Global iter 1, local step 198/2336, fetch 9 new movies!, total: 2973
# Global iter 1, local step 199/2336, fetch 10 new movies!, total: 2983
# Global iter 1, local step 200/2336, fetch 0 new movies!, total: 2983
# Global iter 1, local step 201/2336, fetch 3 new movies!, total: 2986
# Global iter 1, local step 202/2336, fetch 5 new movies!, total: 2991
# Global iter 1, local step 203/2336, fetch 3 new movies!, total: 2994
# Global iter 1, local step 204/2336, fetch 0 new movies!, total: 2994
# Global iter 1, local step 205/2336, fetch 0 new movies!, total: 2994
# Global iter 1, local step 206/2336, fetch 1 new movies!, total: 2995
# Global iter 1, local step 207/2336, fetch 9 new movies!, total: 3004
# Global iter 1, local step 208/2336, fetch 0 new movies!, total: 3004
# Global iter 1, local step 209/2336, fetch 0 new movies!, total: 3004
# Global iter 1, local step 210/2336, fetch 0 new movies!, total: 3004
# Global iter 1, local step 211/2336, fetch 0 new movies!, total: 3004
# Global iter 1, local step 212/2336, fetch 2 new movies!, total: 3006
# Global iter 1, local step 213/2336, fetch 0 new movies!, total: 3006
# Global iter 1, local step 214/2336, fetch 5 new movies!, total: 3011
# Global iter 1, local step 215/2336, fetch 6 new movies!, total: 3017
# Global iter 1, local step 216/2336, fetch 0 new movies!, total: 3017
# Global iter 1, local step 217/2336, fetch 0 new movies!, total: 3017
# Global iter 1, local step 218/2336, fetch 7 new movies!, total: 3024
# Global iter 1, local step 219/2336, fetch 0 new movies!, total: 3024
# Global iter 1, local step 220/2336, fetch 0 new movies!, total: 3024
# Global iter 1, local step 221/2336, fetch 7 new movies!, total: 3031
# Global iter 1, local step 222/2336, fetch 3 new movies!, total: 3034
# Global iter 1, local step 223/2336, fetch 3 new movies!, total: 3037
# Global iter 1, local step 224/2336, fetch 0 new movies!, total: 3037
# Global iter 1, local step 225/2336, fetch 5 new movies!, total: 3042
# Global iter 1, local step 226/2336, fetch 0 new movies!, total: 3042
# Global iter 1, local step 227/2336, fetch 0 new movies!, total: 3042
# Global iter 1, local step 228/2336, fetch 1 new movies!, total: 3043
# Global iter 1, local step 229/2336, fetch 0 new movies!, total: 3043
# Global iter 1, local step 230/2336, fetch 6 new movies!, total: 3049
# Global iter 1, local step 231/2336, fetch 2 new movies!, total: 3051
# Global iter 1, local step 232/2336, fetch 6 new movies!, total: 3057
# Global iter 1, local step 233/2336, fetch 3 new movies!, total: 3060
# Global iter 1, local step 234/2336, fetch 7 new movies!, total: 3067
# Global iter 1, local step 235/2336, fetch 4 new movies!, total: 3071
# Global iter 1, local step 236/2336, fetch 3 new movies!, total: 3074
# Global iter 1, local step 237/2336, fetch 0 new movies!, total: 3074
# Global iter 1, local step 238/2336, fetch 3 new movies!, total: 3077
# Global iter 1, local step 239/2336, fetch 2 new movies!, total: 3079
# Global iter 1, local step 240/2336, fetch 0 new movies!, total: 3079
# Global iter 1, local step 241/2336, fetch 2 new movies!, total: 3081
# Global iter 1, local step 242/2336, fetch 5 new movies!, total: 3086
# Global iter 1, local step 243/2336, fetch 0 new movies!, total: 3086
# Global iter 1, local step 244/2336, fetch 3 new movies!, total: 3089
# Global iter 1, local step 245/2336, fetch 0 new movies!, total: 3089
# Global iter 1, local step 246/2336, fetch 0 new movies!, total: 3089
# Global iter 1, local step 247/2336, fetch 3 new movies!, total: 3092
# Global iter 1, local step 248/2336, fetch 11 new movies!, total: 3103
# Global iter 1, local step 249/2336, fetch 7 new movies!, total: 3110
# Global iter 1, local step 250/2336, fetch 4 new movies!, total: 3114
# Global iter 1, local step 251/2336, fetch 0 new movies!, total: 3114
# Global iter 1, local step 252/2336, fetch 9 new movies!, total: 3123
# Global iter 1, local step 253/2336, fetch 3 new movies!, total: 3126
# Global iter 1, local step 254/2336, fetch 7 new movies!, total: 3133
# Global iter 1, local step 255/2336, fetch 6 new movies!, total: 3139
# Global iter 1, local step 256/2336, fetch 0 new movies!, total: 3139
# Global iter 1, local step 257/2336, fetch 0 new movies!, total: 3139
# Global iter 1, local step 258/2336, fetch 3 new movies!, total: 3142
# Global iter 1, local step 259/2336, fetch 3 new movies!, total: 3145
# Global iter 1, local step 260/2336, fetch 1 new movies!, total: 3146
# Global iter 1, local step 261/2336, fetch 1 new movies!, total: 3147
# Global iter 1, local step 262/2336, fetch 2 new movies!, total: 3149
# Global iter 1, local step 263/2336, fetch 0 new movies!, total: 3149
# Global iter 1, local step 264/2336, fetch 2 new movies!, total: 3151
# Global iter 1, local step 265/2336, fetch 0 new movies!, total: 3151
# Global iter 1, local step 266/2336, fetch 0 new movies!, total: 3151
# Global iter 1, local step 267/2336, fetch 0 new movies!, total: 3151
# Global iter 1, local step 268/2336, fetch 5 new movies!, total: 3156
# Global iter 1, local step 269/2336, fetch 6 new movies!, total: 3162
# Global iter 1, local step 270/2336, fetch 7 new movies!, total: 3169
# Global iter 1, local step 271/2336, fetch 0 new movies!, total: 3169
# Global iter 1, local step 272/2336, fetch 3 new movies!, total: 3172
# Global iter 1, local step 273/2336, fetch 2 new movies!, total: 3174
# Global iter 1, local step 274/2336, fetch 5 new movies!, total: 3179
# Global iter 1, local step 275/2336, fetch 0 new movies!, total: 3179
# Global iter 1, local step 276/2336, fetch 0 new movies!, total: 3179
# Global iter 1, local step 277/2336, fetch 1 new movies!, total: 3180
# Global iter 1, local step 278/2336, fetch 6 new movies!, total: 3186
# Global iter 1, local step 279/2336, fetch 0 new movies!, total: 3186
# Global iter 1, local step 280/2336, fetch 0 new movies!, total: 3186
# Global iter 1, local step 281/2336, fetch 3 new movies!, total: 3189
# Global iter 1, local step 282/2336, fetch 8 new movies!, total: 3197
# Global iter 1, local step 283/2336, fetch 11 new movies!, total: 3208
# Global iter 1, local step 284/2336, fetch 2 new movies!, total: 3210
# Global iter 1, local step 285/2336, fetch 0 new movies!, total: 3210
# Global iter 1, local step 286/2336, fetch 6 new movies!, total: 3216
# Global iter 1, local step 287/2336, fetch 0 new movies!, total: 3216
# Global iter 1, local step 288/2336, fetch 0 new movies!, total: 3216
# Global iter 1, local step 289/2336, fetch 0 new movies!, total: 3216
# Global iter 1, local step 290/2336, fetch 2 new movies!, total: 3218
# Global iter 1, local step 291/2336, fetch 0 new movies!, total: 3218
# Global iter 1, local step 292/2336, fetch 4 new movies!, total: 3222
# Global iter 1, local step 293/2336, fetch 6 new movies!, total: 3228
# Global iter 1, local step 294/2336, fetch 3 new movies!, total: 3231
# Global iter 1, local step 295/2336, fetch 6 new movies!, total: 3237
# Global iter 1, local step 296/2336, fetch 4 new movies!, total: 3241
# Global iter 1, local step 297/2336, fetch 5 new movies!, total: 3246
# Global iter 1, local step 298/2336, fetch 0 new movies!, total: 3246
# Global iter 1, local step 299/2336, fetch 8 new movies!, total: 3254
# Global iter 1, local step 300/2336, fetch 7 new movies!, total: 3261
# Global iter 1, local step 301/2336, fetch 2 new movies!, total: 3263
# Global iter 1, local step 302/2336, fetch 3 new movies!, total: 3266
# Global iter 1, local step 303/2336, fetch 3 new movies!, total: 3269
# Global iter 1, local step 304/2336, fetch 3 new movies!, total: 3272
# Global iter 1, local step 305/2336, fetch 5 new movies!, total: 3277
# Global iter 1, local step 306/2336, fetch 1 new movies!, total: 3278
# Global iter 1, local step 307/2336, fetch 0 new movies!, total: 3278
# Global iter 1, local step 308/2336, fetch 4 new movies!, total: 3282
# Global iter 1, local step 309/2336, fetch 8 new movies!, total: 3290
# Global iter 1, local step 310/2336, fetch 0 new movies!, total: 3290
# Global iter 1, local step 311/2336, fetch 7 new movies!, total: 3297
# Global iter 1, local step 312/2336, fetch 6 new movies!, total: 3303
# Global iter 1, local step 313/2336, fetch 4 new movies!, total: 3307
# Global iter 1, local step 314/2336, fetch 4 new movies!, total: 3311
# Global iter 1, local step 315/2336, fetch 2 new movies!, total: 3313
# Global iter 1, local step 316/2336, fetch 9 new movies!, total: 3322
# Global iter 1, local step 317/2336, fetch 0 new movies!, total: 3322
# Global iter 1, local step 318/2336, fetch 8 new movies!, total: 3330
# Global iter 1, local step 319/2336, fetch 0 new movies!, total: 3330
# Global iter 1, local step 320/2336, fetch 2 new movies!, total: 3332
# Global iter 1, local step 321/2336, fetch 0 new movies!, total: 3332
# Global iter 1, local step 322/2336, fetch 0 new movies!, total: 3332
# Global iter 1, local step 323/2336, fetch 0 new movies!, total: 3332
# Global iter 1, local step 324/2336, fetch 5 new movies!, total: 3337
# Global iter 1, local step 325/2336, fetch 0 new movies!, total: 3337
# Global iter 1, local step 326/2336, fetch 7 new movies!, total: 3344
# Global iter 1, local step 327/2336, fetch 8 new movies!, total: 3352
# Global iter 1, local step 328/2336, fetch 0 new movies!, total: 3352
# Global iter 1, local step 329/2336, fetch 0 new movies!, total: 3352
# Global iter 1, local step 330/2336, fetch 2 new movies!, total: 3354
# Global iter 1, local step 331/2336, fetch 0 new movies!, total: 3354
# Global iter 1, local step 332/2336, fetch 3 new movies!, total: 3357
# Global iter 1, local step 333/2336, fetch 2 new movies!, total: 3359
# Global iter 1, local step 334/2336, fetch 7 new movies!, total: 3366
# Global iter 1, local step 335/2336, fetch 6 new movies!, total: 3372
# Global iter 1, local step 336/2336, fetch 1 new movies!, total: 3373
# Global iter 1, local step 337/2336, fetch 1 new movies!, total: 3374
# Global iter 1, local step 338/2336, fetch 0 new movies!, total: 3374
# Global iter 1, local step 339/2336, fetch 1 new movies!, total: 3375
# Global iter 1, local step 340/2336, fetch 0 new movies!, total: 3375
# Global iter 1, local step 341/2336, fetch 0 new movies!, total: 3375
# Global iter 1, local step 342/2336, fetch 0 new movies!, total: 3375
# Global iter 1, local step 343/2336, fetch 0 new movies!, total: 3375
# Global iter 1, local step 344/2336, fetch 0 new movies!, total: 3375
# Global iter 1, local step 345/2336, fetch 1 new movies!, total: 3376
# Global iter 1, local step 346/2336, fetch 1 new movies!, total: 3377
# Global iter 1, local step 347/2336, fetch 4 new movies!, total: 3381
# Global iter 1, local step 348/2336, fetch 7 new movies!, total: 3388
# Global iter 1, local step 349/2336, fetch 0 new movies!, total: 3388
# Global iter 1, local step 350/2336, fetch 0 new movies!, total: 3388
# Global iter 1, local step 351/2336, fetch 4 new movies!, total: 3392
# Global iter 1, local step 352/2336, fetch 6 new movies!, total: 3398
# Global iter 1, local step 353/2336, fetch 8 new movies!, total: 3406
# Global iter 1, local step 354/2336, fetch 7 new movies!, total: 3413
# Global iter 1, local step 355/2336, fetch 5 new movies!, total: 3418
# Global iter 1, local step 356/2336, fetch 0 new movies!, total: 3418
# Global iter 1, local step 357/2336, fetch 0 new movies!, total: 3418
# Global iter 1, local step 358/2336, fetch 1 new movies!, total: 3419
# Global iter 1, local step 359/2336, fetch 5 new movies!, total: 3424
# Global iter 1, local step 360/2336, fetch 0 new movies!, total: 3424
# Global iter 1, local step 361/2336, fetch 1 new movies!, total: 3425
# Global iter 1, local step 362/2336, fetch 2 new movies!, total: 3427
# Global iter 1, local step 363/2336, fetch 3 new movies!, total: 3430
# Global iter 1, local step 364/2336, fetch 5 new movies!, total: 3435
# Global iter 1, local step 365/2336, fetch 0 new movies!, total: 3435
# Global iter 1, local step 366/2336, fetch 3 new movies!, total: 3438
# Global iter 1, local step 367/2336, fetch 0 new movies!, total: 3438
# Global iter 1, local step 368/2336, fetch 0 new movies!, total: 3438
# Global iter 1, local step 369/2336, fetch 6 new movies!, total: 3444
# Global iter 1, local step 370/2336, fetch 3 new movies!, total: 3447
# Global iter 1, local step 371/2336, fetch 4 new movies!, total: 3451
# Global iter 1, local step 372/2336, fetch 5 new movies!, total: 3456
# Global iter 1, local step 373/2336, fetch 7 new movies!, total: 3463
# Global iter 1, local step 374/2336, fetch 6 new movies!, total: 3469
# Global iter 1, local step 375/2336, fetch 0 new movies!, total: 3469
# Global iter 1, local step 376/2336, fetch 2 new movies!, total: 3471
# Global iter 1, local step 377/2336, fetch 1 new movies!, total: 3472
# Global iter 1, local step 378/2336, fetch 1 new movies!, total: 3473
# Global iter 1, local step 379/2336, fetch 2 new movies!, total: 3475
# -----------------------------------------------------------------------
# TypeError                             Traceback (most recent call last)
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     385             try:  # Python 2.7, use buffering of HTTP responses
# --> 386                 httplib_response = conn.getresponse(buffering=True)
#     387             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                     Traceback (most recent call last)
# <ipython-input-40-5bcc321eafbf> in <module>()
#      41
#      42 # movies = parse_movieURL(home_url)
# ---> 43 new_movies = collect_movieURL(home_url, movies, 2)
#      44 # a = parse_movieURL(home_url)
#      45 # b = parse_movieURL('https://movie.douban.com/subject/22266126/')
#
# <ipython-input-40-5bcc321eafbf> in collect_movieURL(home_url, movies_prime, max_iter)
#      30         totalNum = len(movies)
#      31         for sub_step, url in enumerate(new_movies_temp):
# ---> 32             movies_temp = parse_movieURL(url) - movies
#      33             new_movies = (new_movies | movies_temp)
#      34             movies = movies | new_movies
#
# <ipython-input-40-5bcc321eafbf> in parse_movieURL(url, home)
#      13
#      14 def parse_movieURL(url, home='https://movie.douban.com'):
# ---> 15     text = get_URL(url)
#      16     movie_pattern = re.compile('/subject/[0-9]+?/')
#      17     movie_index = movie_pattern.findall(text)
#
# <ipython-input-40-5bcc321eafbf> in get_URL(url)
#       3 def get_URL(url):
#       4     headers = {'user-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:54.0) Gecko/20100101 Firefox/54.0'}
# ----> 5     response = requests.get(url, headers=headers)
#       6     return response.text
#       7
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/api.py in get(url, params, **kwargs)
#      68
#      69     kwargs.setdefault('allow_redirects', True)
# ---> 70     return request('get', url, params=params, **kwargs)
#      71
#      72
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/api.py in request(method, url, **kwargs)
#      54     # cases, and look like a memory leak in others.
#      55     with sessions.Session() as session:
# ---> 56         return session.request(method=method, url=url, **kwargs)
#      57
#      58
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     473         }
#     474         send_kwargs.update(settings)
# --> 475         resp = self.send(prep, **send_kwargs)
#     476
#     477         return resp
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     594
#     595         # Send the request
# --> 596         r = adapter.send(request, **kwargs)
#     597
#     598         # Total elapsed time of the request (approximately)
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     421                     decode_content=False,
#     422                     retries=self.max_retries,
# --> 423                     timeout=timeout
#     424                 )
#     425
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, **response_kw)
#     593                                                   timeout=timeout_obj,
#     594                                                   body=body, headers=headers,
# --> 595                                                   chunked=chunked)
#     596
#     597             # If we're going to release the connection in ``finally:``, then
#
# /home/jeff/anaconda3/lib/python3.5/site-packages/requests/packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     387             except TypeError:  # Python 2.6 and older, Python 3
#     388                 try:
# --> 389                     httplib_response = conn.getresponse()
#     390                 except Exception as e:
#     391                     # Remove the TypeError from the exception chain in Python 3;
#
# /home/jeff/anaconda3/lib/python3.5/http/client.py in getresponse(self)
#    1195         try:
#    1196             try:
# -> 1197                 response.begin()
#    1198             except ConnectionError:
#    1199                 self.close()
#
# /home/jeff/anaconda3/lib/python3.5/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /home/jeff/anaconda3/lib/python3.5/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /home/jeff/anaconda3/lib/python3.5/socket.py in readinto(self, b)
#     573         while True:
#     574             try:
# --> 575                 return self._sock.recv_into(b)
#     576             except timeout:
#     577                 self._timeout_occurred = True
#
# /home/jeff/anaconda3/lib/python3.5/ssl.py in recv_into(self, buffer, nbytes, flags)
#     927                   "non-zero flags not allowed in calls to recv_into() on %s" %
#     928                   self.__class__)
# --> 929             return self.read(nbytes, buffer)
#     930         else:
#     931             return socket.recv_into(self, buffer, nbytes, flags)
#
# /home/jeff/anaconda3/lib/python3.5/ssl.py in read(self, len, buffer)
#     789             raise ValueError("Read on closed or unwrapped SSL socket.")
#     790         try:
# --> 791             return self._sslobj.read(len, buffer)
#     792         except SSLError as x:
#     793             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# /home/jeff/anaconda3/lib/python3.5/ssl.py in read(self, len, buffer)
#     573         """
#     574         if buffer is not None:
# --> 575             v = self._sslobj.read(len, buffer)
#     576         else:
#     577             v = self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(movies)
# Out:
# 2336
